# %% [markdown]
# ### Cifar-10 이미지 분류 v1

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2023
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 탐색 및 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.xticks([]), plt.yticks([])
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: scaling
X_train = X_train / 255.
X_test = X_test / 255.

# %%
# y data : one hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가 : 이전 정해진 모델 copy

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1250858 (4.77 MB)
# Trainable params: 1250858 (4.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

# %%
model_path = 'models/best_cifar10-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=5)

# %%
hist = model.fit(X_train, Y_train, validation_split=0.2,
                 epochs=100, batch_size=32, callbacks=[mc,es])
# Out:
# Epoch 1/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.6031 - accuracy: 0.4100
# Epoch 1: val_loss improved from inf to 1.33583, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 22s 7ms/step - loss: 1.6026 - accuracy: 0.4103 - val_loss: 1.3358 - val_accuracy: 0.5305
# Epoch 2/100
#    8/1250 [..............................] - ETA: 9s - loss: 1.2183 - accuracy: 0.5430
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.2224 - accuracy: 0.5651
# Epoch 2: val_loss improved from 1.33583 to 1.03641, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.2211 - accuracy: 0.5655 - val_loss: 1.0364 - val_accuracy: 0.6340
# Epoch 3/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 1.0619 - accuracy: 0.6247
# Epoch 3: val_loss improved from 1.03641 to 0.96174, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.0613 - accuracy: 0.6248 - val_loss: 0.9617 - val_accuracy: 0.6563
# Epoch 4/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9620 - accuracy: 0.6597
# Epoch 4: val_loss improved from 0.96174 to 0.95963, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9619 - accuracy: 0.6597 - val_loss: 0.9596 - val_accuracy: 0.6647
# Epoch 5/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.8842 - accuracy: 0.6882
# Epoch 5: val_loss improved from 0.95963 to 0.81703, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.8843 - accuracy: 0.6880 - val_loss: 0.8170 - val_accuracy: 0.7104
# Epoch 6/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8359 - accuracy: 0.7078
# Epoch 6: val_loss improved from 0.81703 to 0.77214, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.8361 - accuracy: 0.7078 - val_loss: 0.7721 - val_accuracy: 0.7310
# Epoch 7/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7825 - accuracy: 0.7235
# Epoch 7: val_loss did not improve from 0.77214
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7824 - accuracy: 0.7235 - val_loss: 0.7731 - val_accuracy: 0.7382
# Epoch 8/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7439 - accuracy: 0.7391
# Epoch 8: val_loss improved from 0.77214 to 0.73834, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.7438 - accuracy: 0.7391 - val_loss: 0.7383 - val_accuracy: 0.7512
# Epoch 9/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7135 - accuracy: 0.7497
# Epoch 9: val_loss improved from 0.73834 to 0.72908, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.7134 - accuracy: 0.7499 - val_loss: 0.7291 - val_accuracy: 0.7489
# Epoch 10/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6829 - accuracy: 0.7593
# Epoch 10: val_loss improved from 0.72908 to 0.70147, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6828 - accuracy: 0.7593 - val_loss: 0.7015 - val_accuracy: 0.7619
# Epoch 11/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6687 - accuracy: 0.7626
# Epoch 11: val_loss did not improve from 0.70147
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6687 - accuracy: 0.7626 - val_loss: 0.7208 - val_accuracy: 0.7525
# Epoch 12/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6395 - accuracy: 0.7735
# Epoch 12: val_loss improved from 0.70147 to 0.68848, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6395 - accuracy: 0.7735 - val_loss: 0.6885 - val_accuracy: 0.7677
# Epoch 13/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6256 - accuracy: 0.7798
# Epoch 13: val_loss did not improve from 0.68848
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6259 - accuracy: 0.7796 - val_loss: 0.7124 - val_accuracy: 0.7534
# Epoch 14/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6052 - accuracy: 0.7872
# Epoch 14: val_loss did not improve from 0.68848
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6055 - accuracy: 0.7870 - val_loss: 0.7130 - val_accuracy: 0.7593
# Epoch 15/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5852 - accuracy: 0.7932
# Epoch 15: val_loss did not improve from 0.68848
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5852 - accuracy: 0.7932 - val_loss: 0.7151 - val_accuracy: 0.7608
# Epoch 16/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.5702 - accuracy: 0.7996
# Epoch 16: val_loss did not improve from 0.68848
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5703 - accuracy: 0.7996 - val_loss: 0.6910 - val_accuracy: 0.7694
# Epoch 17/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.5625 - accuracy: 0.8018
# Epoch 17: val_loss improved from 0.68848 to 0.66891, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5629 - accuracy: 0.8016 - val_loss: 0.6689 - val_accuracy: 0.7724
# Epoch 18/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.5461 - accuracy: 0.8107
# Epoch 18: val_loss improved from 0.66891 to 0.66734, saving model to models/best_cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5464 - accuracy: 0.8107 - val_loss: 0.6673 - val_accuracy: 0.7760
# Epoch 19/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.8090
# Epoch 19: val_loss did not improve from 0.66734
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5381 - accuracy: 0.8090 - val_loss: 0.6874 - val_accuracy: 0.7680
# Epoch 20/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5282 - accuracy: 0.8145
# Epoch 20: val_loss did not improve from 0.66734
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5283 - accuracy: 0.8145 - val_loss: 0.6761 - val_accuracy: 0.7774
# Epoch 21/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.5174 - accuracy: 0.8189
# Epoch 21: val_loss did not improve from 0.66734
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5173 - accuracy: 0.8191 - val_loss: 0.6909 - val_accuracy: 0.7762
# Epoch 22/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.5057 - accuracy: 0.8212
# Epoch 22: val_loss did not improve from 0.66734
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5054 - accuracy: 0.8214 - val_loss: 0.6904 - val_accuracy: 0.7654
# Epoch 23/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.5004 - accuracy: 0.8219
# Epoch 23: val_loss did not improve from 0.66734
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5008 - accuracy: 0.8219 - val_loss: 0.6729 - val_accuracy: 0.7745

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6942 - accuracy: 0.7719
# [0.6941630244255066, 0.7718999981880188]

# %% [markdown]
# - 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('epoch')
plt.title('Cifar-10 CNN Model V1')
plt.show()
